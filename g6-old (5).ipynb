# %% [markdown]
# # **Data Collection**

# %%
import os
import pandas as pd

dataset_train_root =  r"/kaggle/input/smith-image/IMG-FER-SKY/train"
categories = os.listdir(dataset_train_root)

value_counts = {}

for category in categories:
    images_count = len(os.listdir(os.path.join(dataset_train_root, category)))
    value_counts[category] = images_count

df = pd.DataFrame(list(value_counts.items()), columns=['Emotion', 'Count'])
print(df)

# %%
dataset_test_root =   r"/kaggle/input/smith-image/IMG-FER-SKY/test" 
categories = os.listdir(dataset_test_root)

value_counts = {}

for category in categories:
    images_count = len(os.listdir(os.path.join(dataset_test_root, category)))
    value_counts[category] = images_count

df = pd.DataFrame(list(value_counts.items()), columns=['Emotion', 'Count'])
print(df)

# %% [markdown]
# # **Traditional Image Processing**

# %%
import cv2
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# **R Channel**

# %%
def extract_red_channel(image_path):
    
    img = cv2.imread(image_path)

    red_channel = img[:, :, 2]

    return red_channel

image_path1 = r'/kaggle/input/smith-image/IMG-FER-SKY/test/angry/PrivateTest_10131363.jpg'
image_path2 = r'/kaggle/input/smith-image/IMG-FER-SKY/test/disgust/PrivateTest_11895083.jpg'

red_channel1 = extract_red_channel(image_path1)
red_channel2 = extract_red_channel(image_path2)

df = pd.DataFrame({
    'Red Channel Image 1': red_channel1.ravel(),
    'Red Channel Image 2': red_channel2.ravel()
})
print(df)

plt.figure(figsize=(10, 6))
plt.hist(df['Red Channel Image 1'], bins=256, color='red', alpha=0.5, label='Image 1')
plt.hist(df['Red Channel Image 2'], bins=256, color='blue', alpha=0.5, label='Image 2')
plt.title('Histogram Comparison of Red Channel Values')
plt.xlabel('Pixel Value')
plt.ylabel('Frequency')
plt.legend()
plt.show()
# Out:
#       Red Channel Image 1  Red Channel Image 2
# 0                      46                   22
# 1                      34                   13
# 2                      26                   14
# 3                      23                   16
# 4                      12                   13
# ...                   ...                  ...
# 2299                  131                   30
# 2300                  128                   85
# 2301                  165                  104
# 2302                  180                  216
# 2303                  189                  255
#
# [2304 rows x 2 columns]

# %% [markdown]
# **Green Channel**

# %%
def extract_green_channel(image_path):
    
    img = cv2.imread(image_path)

    green_channel = img[:, :, 1]

    return green_channel

image_path1 = r'/kaggle/input/smith-image/IMG-FER-SKY/test/angry/PrivateTest_10131363.jpg'
image_path2 = r'/kaggle/input/smith-image/IMG-FER-SKY/test/disgust/PrivateTest_11895083.jpg'

green_channel1 = extract_green_channel(image_path1)
green_channel2 = extract_green_channel(image_path2)

df = pd.DataFrame({
    'Green Channel Image 1': green_channel1.ravel(),
    'Green Channel Image 2': green_channel2.ravel()
})
print(df)

plt.figure(figsize=(10, 6))
plt.hist(df['Green Channel Image 1'], bins=256, color='green', alpha=0.5, label='Image 1')
plt.hist(df['Green Channel Image 2'], bins=256, color='orange', alpha=0.5, label='Image 2')
plt.title('Histogram Comparison of Green Channel Values')
plt.xlabel('Pixel Value')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %% [markdown]
# **Blue Channel**

# %%
def extract_blue_channel(image_path):
    
    img = cv2.imread(image_path)

    blue_channel = img[:, :, 0]

    return blue_channel

image_path1 = r'/kaggle/input/smith-image/IMG-FER-SKY/test/angry/PrivateTest_10131363.jpg'
image_path2 = r'/kaggle/input/smith-image/IMG-FER-SKY/test/disgust/PrivateTest_11895083.jpg'

blue_channel1 = extract_blue_channel(image_path1)
blue_channel2 = extract_blue_channel(image_path2)

df = pd.DataFrame({
    'Blue Channel Image 1': blue_channel1.ravel(),
    'Blue Channel Image 2': blue_channel2.ravel()
})
print(df)

plt.figure(figsize=(10, 6))
plt.hist(df['Blue Channel Image 1'], bins=256, color='blue', alpha=0.5, label='Image 1')
plt.hist(df['Blue Channel Image 2'], bins=256, color='green', alpha=0.5, label='Image 2')
plt.title('Histogram Comparison of Blue Channel Values')
plt.xlabel('Pixel Value')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %% [markdown]
# **Hue Channel**

# %%
def extract_hue_channel(image_path):
    
    img_bgr = cv2.imread(image_path)

    img_hsv = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2HSV)

    hue_channel = img_hsv[:, :, 0]

    return hue_channel

image_path1 = r'/kaggle/input/smith-image/IMG-FER-SKY/test/angry/PrivateTest_10131363.jpg'
image_path2 = r'/kaggle/input/smith-image/IMG-FER-SKY/test/disgust/PrivateTest_11895083.jpg'

hue_channel1 = extract_hue_channel(image_path1)
hue_channel2 = extract_hue_channel(image_path2)

df = pd.DataFrame({
    'Hue Channel Image 1': hue_channel1.ravel(),
    'Hue Channel Image 2': hue_channel2.ravel()
})
print(df)

plt.figure(figsize=(10, 6))
plt.hist(df['Hue Channel Image 1'], bins=256, color='orange', alpha=0.5, label='Image 1')
plt.hist(df['Hue Channel Image 2'], bins=256, color='purple', alpha=0.5, label='Image 2')
plt.title('Histogram Comparison of Hue Channel Values')
plt.xlabel('Pixel Value')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %% [markdown]
# **Saturation Channel**

# %%
def extract_saturation_channel(image_path):
   
    img_bgr = cv2.imread(image_path)

    img_hsv = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2HSV)

    saturation_channel = img_hsv[:, :, 1]

    return saturation_channel

image_path1 = r'/kaggle/input/smith-image/IMG-FER-SKY/test/angry/PrivateTest_10131363.jpg'
image_path2 = r'/kaggle/input/smith-image/IMG-FER-SKY/test/disgust/PrivateTest_11895083.jpg'


saturation_channel1 = extract_saturation_channel(image_path1)
saturation_channel2 = extract_saturation_channel(image_path2)

df = pd.DataFrame({
    'Saturation Channel Image 1': saturation_channel1.ravel(),
    'Saturation Channel Image 2': saturation_channel2.ravel()
})
print(df)

plt.figure(figsize=(10, 6))
plt.hist(df['Saturation Channel Image 1'], bins=256, color='orange', alpha=0.5, label='Image 1')
plt.hist(df['Saturation Channel Image 2'], bins=256, color='purple', alpha=0.5, label='Image 2')
plt.title('Histogram Comparison of Saturation Channel Values')
plt.xlabel('Pixel Value')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %% [markdown]
# **Value Channel**

# %%
def extract_value_channel(image_path):
    
    img_bgr = cv2.imread(image_path)

    img_hsv = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2HSV)

    value_channel = img_hsv[:, :, 2]

    return value_channel

image_path1 = r'/kaggle/input/smith-image/IMG-FER-SKY/test/angry/PrivateTest_10131363.jpg'
image_path2 = r'/kaggle/input/smith-image/IMG-FER-SKY/test/disgust/PrivateTest_11895083.jpg'

value_channel1 = extract_value_channel(image_path1)
value_channel2 = extract_value_channel(image_path2)

df = pd.DataFrame({
    'Value Channel Image 1': value_channel1.ravel(),
    'Value Channel Image 2': value_channel2.ravel()
})
print(df)

plt.figure(figsize=(10, 6))
plt.hist(df['Value Channel Image 1'], bins=256, color='orange', alpha=0.5, label='Image 1')
plt.hist(df['Value Channel Image 2'], bins=256, color='purple', alpha=0.5, label='Image 2')
plt.title('Histogram Comparison of Value Channel Values')
plt.xlabel('Pixel Value')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %% [markdown]
# **Lightness Channel**

# %%
def extract_l_channel(image_path):
    img_bgr = cv2.imread(image_path)
    img_lab = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2LAB)
    l_channel = img_lab[:, :, 0]
    return l_channel

image_path1 = r'/kaggle/input/smith-image/IMG-FER-SKY/test/angry/PrivateTest_10131363.jpg'
image_path2 = r'/kaggle/input/smith-image/IMG-FER-SKY/test/disgust/PrivateTest_11895083.jpg'

l_channel1 = extract_l_channel(image_path1)
l_channel2 = extract_l_channel(image_path2)

df = pd.DataFrame({
    'L Channel Image 1': l_channel1.ravel(),
    'L Channel Image 2': l_channel2.ravel()
})
print(df)

plt.figure(figsize=(10, 6))
plt.hist(df['L Channel Image 1'], bins=256, color='orange', alpha=0.5, label='Image 1')
plt.hist(df['L Channel Image 2'], bins=256, color='purple', alpha=0.5, label='Image 2')
plt.title('Histogram Comparison of L Channel Values')
plt.xlabel('Pixel Value')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %% [markdown]
# A Channel

# %%
def extract_a_channel(image_path):
    
    img_bgr = cv2.imread(image_path)

    img_lab = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2LAB)

    a_channel = img_lab[:, :, 1]

    return a_channel


image_path1 = r'/kaggle/input/smith-image/IMG-FER-SKY/test/angry/PrivateTest_10131363.jpg'
image_path2 = r'/kaggle/input/smith-image/IMG-FER-SKY/test/disgust/PrivateTest_11895083.jpg'

a_channel1 = extract_a_channel(image_path1)
a_channel2 = extract_a_channel(image_path2)

df = pd.DataFrame({
    'A Channel Image 1': a_channel1.ravel(),
    'A Channel Image 2': a_channel2.ravel()
})
print(df)

plt.figure(figsize=(10, 6))
plt.hist(df['A Channel Image 1'], bins=256, color='green', alpha=0.5, label='Image 1')
plt.hist(df['A Channel Image 2'], bins=256, color='magenta', alpha=0.5, label='Image 2')
plt.title('Histogram Comparison of A Channel Values')
plt.xlabel('Pixel Value')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %% [markdown]
# **B Channel**

# %%
def extract_b_channel(image_path):

    img_bgr = cv2.imread(image_path)

  
    img_lab = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2LAB)

    
    b_channel = img_lab[:, :, 2]

    return b_channel

image_path1 = r'/kaggle/input/smith-image/IMG-FER-SKY/test/angry/PrivateTest_10131363.jpg'
image_path2 = r'/kaggle/input/smith-image/IMG-FER-SKY/test/disgust/PrivateTest_11895083.jpg'

b_channel1 = extract_b_channel(image_path1)
b_channel2 = extract_b_channel(image_path2)

df = pd.DataFrame({
    'B Channel Image 1': b_channel1.ravel(),
    'B Channel Image 2': b_channel2.ravel()
})
print(df)

plt.figure(figsize=(10, 6))
plt.hist(df['B Channel Image 1'], bins=256, color='blue', alpha=0.5, label='Image 1')
plt.hist(df['B Channel Image 2'], bins=256, color='yellow', alpha=0.5, label='Image 2')
plt.title('Histogram Comparison of B Channel Values')
plt.xlabel('Pixel Value')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %% [markdown]
# # **Machine Learning Models**

# %% [markdown]
# **KNN**

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report

# Assuming you have labels for the images (e.g., 'angry', 'disgust')
# Replace these labels with the actual labels of your dataset
labels = ['angry', 'disgust']

# Assuming you have dataframes df_red, df_green, ..., df_b for the corresponding channels
# Concatenate the dataframes vertically to create the feature matrix
features_df = pd.concat([df_red, df_green, df_blue, df_hue, df_saturation, df_value, df_l, df_a, df_b], axis=1)

# Create a target array with corresponding labels for each row in the features_df
targets = labels * (len(features_df) // len(labels))

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features_df, targets, test_size=0.2, random_state=42)

# Initialize the kNN model with k=3 (you can adjust this parameter)
knn_model = KNeighborsClassifier(n_neighbors=3)

# Train the model
knn_model.fit(X_train, y_train)

# Make predictions on the test set
predictions = knn_model.predict(X_test)
# Evaluate the model
accuracy = accuracy_score(y_test, predictions)
print(f'Accuracy: {accuracy:.2f}')

# Print classification report
print('\nClassification Report:\n', classification_report(y_test, predictions))

# %%
# !pip install scikit-image

# %% [markdown]
# **Random Forest**

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
​
# Assuming you have labels for the images (e.g., 'angry', 'disgust')
# Replace these labels with the actual labels of your dataset
labels = ['angry', 'disgust']
​
# Assuming you have dataframes df_red, df_green, ..., df_b for the corresponding channels
# Concatenate the dataframes horizontally to create the feature matrix
features_df = pd.concat([df_red, df_green, df_blue, df_hue, df_saturation, df_value, df_l, df_a, df_b], axis=1)
​
# Create a target array with corresponding labels for each row in the features_df
targets = labels * (len(features_df) // len(labels))
​
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features_df, targets, test_size=0.2, random_state=42)
​
# Initialize the Random Forest model
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
​
# Train the model
rf_model.fit(X_train, y_train)
​
# Make predictions on the test set
predictions = rf_model.predict(X_test)
​
# Evaluate the model
accuracy = accuracy_score(y_test, predictions)
print(f'Accuracy: {accuracy:.2f}')
​
# Print classification report
print('\nClassification Report:\n', classification_report(y_test, predictions))

# %% [markdown]
# **CNN**

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_dir = r"/kaggle/input/smith-image/IMG-FER-SKY/train"
test_dir = r"/kaggle/input/smith-image/IMG-FER-SKY/test"

train_datagen = ImageDataGenerator(
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    rescale=1./255,
    validation_split=0.2
)

validation_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

train_generator = train_datagen.flow_from_directory(
    directory=r"/kaggle/input/smith-image/IMG-FER-SKY/train",
    target_size=(48, 48),
    batch_size=64,
    class_mode="categorical",
    subset="training"
)

validation_generator = validation_datagen.flow_from_directory(
    directory=r"/kaggle/input/smith-image/IMG-FER-SKY/test",
    target_size=(48, 48),
    batch_size=64,
    class_mode="categorical",
    subset="validation"
)

# %%
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.models import Sequential
from keras.layers import BatchNormalization
import tensorflow as tf 

model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(48,48,3)))
model.add(BatchNormalization())
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(7, activation='softmax'))

model.compile(loss="categorical_crossentropy", optimizer= tf.keras.optimizers.Adam(learning_rate=0.0001), metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping

checkpoint_callback = ModelCheckpoint(
    filepath='model_weights.h5',
    monitor='val_accuracy',
    save_best_only=True,
    save_weights_only=True,
    mode='max',
    verbose=1
)
early_stopping=EarlyStopping(monitor='val_loss',patience=5,restore_best_weights=True)
history = model.fit(
    train_generator,
    steps_per_epoch=len(train_generator),
    epochs=50,
    validation_data=validation_generator,
    validation_steps=len(validation_generator),
    callbacks=[early_stopping,checkpoint_callback]
)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt
model.load_weights('model_weights.h5')

def predict_emotion(image_path):
    img = image.load_img(image_path, target_size=(48, 48), color_mode="rgb")
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)  
    

    predictions = model.predict(img_array)

    emotion_labels = ["Angry", "Disgust", "Fear", "Happy", "Sad", "Surprise", "Neutral"]
    predicted_emotion = emotion_labels[np.argmax(predictions)]

    plt.imshow(img_array[0, :, :, 0], cmap='gray')  
    plt.title(f'Predicted Emotion: {predicted_emotion}')
    plt.axis('off')
    plt.show()

image_path = input("Enter the path to the image you want to test: ")
predict_emotion(image_path)

# %%
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, classification_report

def predict_emotion(image_path):
    img = image.load_img(image_path, target_size=(48, 48), color_mode="rgb")
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)  
    import random
    emotions = ["Angry", "Disgust", "Fear", "Happy", "Sad", "Surprise", "Neutral"]
    return random.choice(emotions)    
    

test_data = [
    r"/kaggle/input/smith-image/IMG-FER-SKY/test/angry/PrivateTest_10590091.jpg", 
    r"/kaggle/input/smith-image/IMG-FER-SKY/test/disgust/PrivateTest_22382996.jpg",
    r"/kaggle/input/smith-image/IMG-FER-SKY/test/fear/PrivateTest_10306709.jpg",
    r"/kaggle/input/smith-image/IMG-FER-SKY/test/happy/PrivateTest_10516065.jpg",
    r"/kaggle/input/smith-image/IMG-FER-SKY/test/sad/PrivateTest_10814167.jpg",
    r"/kaggle/input/smith-image/IMG-FER-SKY/test/surprise/PrivateTest_1076980.jpg",
    r"/kaggle/input/smith-image/IMG-FER-SKY/test/neutral/PrivateTest_11123843.jpg"
] 

true_labels = [
    "Angry", "Disgust", "Fear", "Happy", "Sad", "Surprise", "Neutral"
]  

predicted_labels = []

for image_path in test_data:
    predicted_emotion = predict_emotion(image_path)
    predicted_labels.append(predicted_emotion)

assert len(true_labels) == len(predicted_labels), "Length of true_labels and predicted_labels must match."

accuracy = accuracy_score(true_labels, predicted_labels)
print(f'Accuracy: {accuracy:.2f}')

f1 = f1_score(true_labels, predicted_labels, average='weighted')
print(f'F1 Score: {f1:.2f}')

emotion_labels = ["Angry", "Disgust", "Fear", "Happy", "Sad", "Surprise", "Neutral"]
report = classification_report(true_labels, predicted_labels, target_names=emotion_labels)
print('Classification Report:')
print(report)

# %%
# !pip install seaborn

# %%
import seaborn as sns 
from sklearn.metrics import confusion_matrix

validation_labels = validation_generator.classes
validation_pred_probs = model.predict(validation_generator)
validation_pred_labels = np.argmax(validation_pred_probs, axis=1)

confusion_mtx = confusion_matrix(validation_labels, validation_pred_labels)
class_names = list(train_generator.class_indices.keys())
sns.set()
sns.heatmap(confusion_mtx, annot=True, fmt='d', cmap='YlGnBu', 
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# %%
from tensorflow.keras.models import save_model
save_model(model, 'model_weights.h5')

# %% [markdown]
# **VGG16 model**

# %%
from tensorflow.keras.models import load_model

# %%
model = load_model('model_weights.h5')

# %%
import tensorflow as tf
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import accuracy_score, f1_score, classification_report
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.optimizers import Adam

# %%
train_dir = r"/kaggle/input/smith-image/IMG-FER-SKY/train"
test_dir = r"/kaggle/input/smith-image/IMG-FER-SKY/test"

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

validation_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

# %%
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(48, 48, 3))

# %%
model = Sequential()
model.add(base_model)
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(7, activation='softmax'))

# %%
model.compile(loss="categorical_crossentropy", optimizer=Adam(learning_rate=0.0001), metrics=['accuracy'])

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(48, 48),
    batch_size=64,
    class_mode="categorical",
    subset="training"
)

validation_generator = validation_datagen.flow_from_directory(
    train_dir,
    target_size=(48, 48),
    batch_size=64,
    class_mode="categorical",
    subset="validation"
)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping

checkpoint_callback = ModelCheckpoint(
    filepath='vgg16_emodel.h5',
    monitor='val_accuracy',
    save_best_only=True,
    save_weights_only=True,
    mode='max',
    verbose=1
)
early_stopping=EarlyStopping(monitor='val_loss',patience=5,restore_best_weights=True)
history = model.fit(
    train_generator,
    steps_per_epoch=len(train_generator),
    epochs=50,
    validation_data=validation_generator,
    validation_steps=len(validation_generator),
    callbacks=[early_stopping,checkpoint_callback]
)

# %%
model.save('vgg16_emodel.h5')

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import load_model
from tensorflow.keras.applications.vgg16 import preprocess_input

model = load_model('vgg16_emodel.h5')

test_data_dir = '/kaggle/input/smith-image/IMG-FER-SKY/test'

img_size = (48, 48)

def load_data(data_dir):
    test_datagen = image.ImageDataGenerator(preprocessing_function=preprocess_input)
    test_generator = test_datagen.flow_from_directory(
        data_dir,
        target_size=img_size,
        batch_size=32,
        class_mode='categorical',  
        shuffle=False
    )
    return test_generator

test_generator = load_data(test_data_dir)

predictions = model.predict(test_generator)

predicted_classes = np.argmax(predictions, axis=1)

true_classes = test_generator.classes

print("Confusion Matrix:")
conf_matrix = confusion_matrix(true_classes, predicted_classes)
print(conf_matrix)

print("\nClassification Report:")
class_report = classification_report(true_classes, predicted_classes)
print(class_report)
